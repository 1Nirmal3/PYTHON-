# %%
for i in range (100,201):
  if i %2==0:
    print(i)
# Out:
# 100
# 102
# 104
# 106
# 108
# 110
# 112
# 114
# 116
# 118
# 120
# 122
# 124
# 126
# 128
# 130
# 132
# 134
# 136
# 138
# 140
# 142
# 144
# 146
# 148
# 150
# 152
# 154
# 156
# 158
# 160
# 162
# 164
# 166
# 168
# 170
# 172
# 174
# 176
# 178
# 180
# 182
# 184
# 186
# 188
# 190
# 192
# 194
# 196
# 198
# 200

# %%
x=int(input("Enter no."))
y=int(input("Enter no."))
z=int(input("Enter no."))
if x>y:
  if x>z:
    print(x)
  else:
    print(z)
else:
  if y>z:
    print(y)
  else:
    print(z)
# Out:
# Enter no.1
# Enter no.2
# Enter no.3
# 3

# %%
fact=1
x=int(input("Enter No.:"))
if x==0:
  print("Factorial of 0 is 1")
else:
  for i in range(1,x+1):
    fact=fact*i
print("Factorial of",x,"is",fact)
# Out:
# Enter No.:7
# Factorial of 7 is 5040

# %%
a=int(input("Enter number whose table you want to print:"))
b=int(input("Enter number till which you want to print the table:"))
for j in range(1,b+1):
  print(a*j)
# Out:
# Enter number whose table you want to print:9
# Enter number till which you want to print the table:10
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %%
mydict = {"name" : "sameer","class" : "any","age" : 18}
for x in mydict.values():
  print(x)
# Out:
# sameer
# any
# 18

# %%
a=(1,2,3)

# %%
a[1]
# Out:
# 2

# %%
a={1,1,2,1,2}

# %%
print (a)
# Out:
# {1, 2}

# %%
sum=0
for i in range(1,101):
  sum=sum+i
print(sum)
# Out:
# 5050
