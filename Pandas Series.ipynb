# %%
import pandas as pd

# %%
item = pd.Series(data=['chocolate',1,'No'],index=['q',5,3])

# %%
item.size
# Out:
# 3

# %%
item.shape
# Out:
# (3,)

# %%
item.index
# Out:
# Index(['q', 5, 3], dtype='object')

# %%
item.values
# Out:
# array(['chocolate', 1, 'No'], dtype=object)

# %%
'chocolate' in item
# Out:
# False

# %%
'q' in item
# Out:
# True

# %%
item[[5,3]]
# Out:
# 5     1
# 3    No
# dtype: object

# %%
item.loc[[3,5]]
# Out:
# 3    No
# 5     1
# dtype: object

# %%
item.iloc[[1,2]]
# Out:
# 5     1
# 3    No
# dtype: object

# %%
item[5]='milk'

# %%
item
# Out:
# q    chocolate
# 5         milk
# 3           No
# dtype: object

# %%
item=item.drop('q')

# %%
item
# Out:
# 5    milk
# 3      No
# dtype: object

# %%
sweets = pd.Series(data=[10,5,7],index=['candies','donuts','ladoos'])

# %%
sweets
# Out:
# candies    10
# donuts      5
# ladoos      7
# dtype: int64

# %%
sweets+2
# Out:
# candies    12
# donuts      7
# ladoos      9
# dtype: int64

# %%
sweets-2
# Out:
# candies    8
# donuts     3
# ladoos     5
# dtype: int64

# %%
sweets*2
# Out:
# candies    20
# donuts     10
# ladoos     14
# dtype: int64

# %%
import numpy as np

# %%
np.sqrt(sweets)
# Out:
# candies    3.162278
# donuts     2.236068
# ladoos     2.645751
# dtype: float64

# %%
np.power(sweets,2)
# Out:
# candies    100
# donuts      25
# ladoos      49
# dtype: int64

# %%
sweets['candies']-4
# Out:
# 6

# %%
sweets[['donuts','ladoos']]*3
# Out:
# donuts    15
# ladoos    21
# dtype: int64

# %%
item={'Pulkit': pd.Series([250,15,70,100],index=['watch','toys','glasses','shirt']),
      'Ashish': pd.Series([120,50,90], index=['pants','books','toys'])}

# %%
cart=pd.DataFrame(item)

# %%
cart
# Out:
#          Pulkit  Ashish
# books       NaN    50.0
# glasses    70.0     NaN
# pants       NaN   120.0
# shirt     100.0     NaN
# toys       15.0    90.0
# watch     250.0     NaN

# %%
Pulkit_cart=pd.DataFrame(item,columns=['Pulkit'])
Pulkit_cart
# Out:
#          Pulkit
# watch       250
# toys         15
# glasses      70
# shirt       100

# %%
selected_item=pd.DataFrame(item,index=['pants','toys'])
selected_item
# Out:
#        Pulkit  Ashish
# pants     NaN     120
# toys     15.0      90

# %%
selected_items=pd.DataFrame(item,columns=['Pulkit'],index=['toys','glasses'])
selected_items
# Out:
#          Pulkit
# toys         15
# glasses      70

# %%
data={'Integers':[1,2,3],
      'Floats':[1.1,2.2,3.3]}

# %%
df=pd.DataFrame(data,index=['label1','label2','label3'])
df
# Out:
#         Integers  Floats
# label1         1     1.1
# label2         2     2.2
# label3         3     3.3

# %%
ListOfValues=[{'apple':20,'mango':15,'orange':30},{'apple':10,'tomato':17,'grapes':35}]
df=pd.DataFrame(ListOfValues)
df
# Out:
#    apple  mango  orange  tomato  grapes
# 0     20   15.0    30.0     NaN     NaN
# 1     10    NaN     NaN    17.0    35.0

# %%
df.index=['personA','personB']

# %%
df
# Out:
#          apple  mango  orange  tomato  grapes
# personA     20   15.0    30.0     NaN     NaN
# personB     10    NaN     NaN    17.0    35.0

# %%
df['corn']=[5,7]

# %%
df['vegies']=df['corn']+df['tomato']

# %%
df
# Out:
#          apple  mango  orange  tomato  grapes  corn  vegies
# personA     20   15.0    30.0     NaN     NaN     5     NaN
# personB     10    NaN     NaN    17.0    35.0     7    24.0

# %%
new_person=[{'apple':15,'banana':17,'corn':3,'orange':5}]
new_df=pd.DataFrame(new_person,index=['personC'])
new_df
# Out:
#          apple  banana  corn  orange
# personC     15      17     3       5

# %%
df=df.append(new_df)

# %%
df.insert(5,'ginger',[7,11,13])

# %%
df.pop('ginger')
df
# Out:
#          apple  mango  orange  tomato  grapes  corn  vegies  banana
# personA     20   15.0    30.0     NaN     NaN     5     NaN     NaN
# personB     10    NaN     NaN    17.0    35.0     7    24.0     NaN
# personC     15    NaN     5.0     NaN     NaN     3     NaN    17.0

# %%
df.drop(['grapes','orange'],axis=1)
df
# Out:
#          apple  mango  orange  tomato  grapes  corn  vegies  banana
# personA     20   15.0    30.0     NaN     NaN     5     NaN     NaN
# personB     10    NaN     NaN    17.0    35.0     7    24.0     NaN
# personC     15    NaN     5.0     NaN     NaN     3     NaN    17.0

# %%
df=df.rename(columns={'banana':'pineapple'})
df
#if you want to change row , instead of columns write index
# Out:
#          apple  mango  orange  tomato  grapes  corn  vegies  pineapple
# personA     20   15.0    30.0     NaN     NaN     5     NaN        NaN
# personB     10    NaN     NaN    17.0    35.0     7    24.0        NaN
# personC     15    NaN     5.0     NaN     NaN     3     NaN       17.0

# %%
df=df.rename(index={'personA':'person1'})
df
# Out:
#          apple  mango  orange  tomato  grapes  corn  vegies  pineapple
# person1     20   15.0    30.0     NaN     NaN     5     NaN        NaN
# personB     10    NaN     NaN    17.0    35.0     7    24.0        NaN
# personC     15    NaN     5.0     NaN     NaN     3     NaN       17.0

# %%
items2=[{'bikes':20,'pants':30,'watches':35,'shirts':15,'shoes':8,'suits':45,},{'watches':10,'glasses':50,'bikes':15,'pants':5,'shirts':2,'shoes':5,'suits':7},{'bikes':20,'pants':30,'watches':35,'glasses':4,'shoes':10}]

# %%
store_items=pd.DataFrame(items2,index=['store 1','store 2','store 3'])

# %%
store_items
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      NaN
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     NaN     10    NaN      4.0

# %%
store_items.fillna(store_items.mean())
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0     27.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     8.5     10   26.0      4.0

# %%
store_items.fillna(0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 1     20     30       35    15.0      8   45.0      0.0
# store 2     15      5       10     2.0      5    7.0     50.0
# store 3     20     30       35     0.0     10    0.0      4.0

# %%
store_items.dropna(axis=0)
# Out:
#          bikes  pants  watches  shirts  shoes  suits  glasses
# store 2     15      5       10     2.0      5    7.0     50.0

# %%
store_items.dropna(axis=1)
# Out:
#          bikes  pants  watches  shoes
# store 1     20     30       35      8
# store 2     15      5       10      5
# store 3     20     30       35     10
