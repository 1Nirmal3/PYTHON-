# %% [markdown]
# # ASSIGNMENT NO:- 2

# %% [raw]
# Q-1)What will be the output after executing the following codes? Do not take the help of compiler
# x=(0,8,9,67,45,9,0)
# y=slice(1,-2)
# x[y]

# %%
#(8, 9, 67, 45)
# Out:
# (8, 9, 67, 45)

# %% [raw]
# Q-2)The method used to increase the length of the list by number of elements in its argument.
#  a)add ()
#  b)insert ()
#  c)extend ()
#  d)pop ()

# %%
#b) insert

# %% [raw]
# Q-3) ADD two sets
# x={1,7,5,4}
# y={8,9,"esh"}

# %%
x.union(y)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-2f346478ebe1> in <module>
# ----> 1 x.add(y)
#
# TypeError: unhashable type: 'set'

# %% [raw]
# Q-4) Find out which of the following code does not work on a tuple
#  x+y
#  sum(x)
#  y[3] = 45
#  len(y)

# %%
#c)y[3]=45

# %% [raw]
# Q-5) Which of the following is not a valid syntax for creating a Set ‘M’ in Python?
#  a)M = set ([11,12,12,13,14,15])
#  b)M = {11,12,13,14}
#  c)M = set ([11,12],[13,14],[14,15])
#  d)M = set ((11,12,13,14))

# %%
#c

# %% [raw]
# Q-6)Which of the following command returns the set of all elements from both sets, a and b
# a={1,4,6,7,6,3}
# b={5,8,9,0,5,3,4}

# %%
a.union(b)
a

# %% [raw]
# Q-7)For dictionary d = {"plum ":0.66, "pears ":1.25,"oranges ":0.50, "apple":0.75 },
# write a code to correctly update the price of oranges to 0.90?

# %%
d = {"plum ":0.66, "pears ":1.25,"oranges ":0.50, "apple":0.75 }
e={"oranges":0.90}
d.update(e)
d
# Out:
# {'apple': 0.75, 'oranges': 0.9, 'oranges ': 0.5, 'pears ': 1.25, 'plum ': 0.66}

# %% [raw]
# Q-8)What will be the output,do yourself without taking the help of compiler?
# c={}
# c[1]=12
# c["1"]=12
# c[1]+=1

# %%
{1: 13, '1': 12}

# %% [raw]
# Q-9)Which of the following is not possible in sequence datatypes?
#  a)Create a tuple inside a set
#  b)Create a list inside a set
#  c)Create a list inside a tuple
#  d)Create a set inside a list

# %%
#b)

# %% [raw]
# Q-10)Variable ‘a’ is defined as
#        a = "gOOd moRning"
#  write a code to convert ‘a’ from ‘gOOd moRning’ to ‘Good Morning’ is:-

# %% [raw]
# Q-11) Create a list called “Stationery” which encompasses all the below variables
#
#       Product = ['Pencil', 'Pen', 'Eraser', 'Pencil Box', 'Scale']
#       Price= [5, 10, 2, 20, 12]
#       Brand = ['Camlin', 'Rotomac', 'Nataraj', 'Camel', 'Apsara']

# %%
Product = ['Pencil', 'Pen', 'Eraser', 'Pencil Box', 'Scale']
Price= [5, 10, 2, 20, 12]  
Brand = ['Camlin', 'Rotomac', 'Nataraj', 'Camel', 'Apsara']
stationery=[]
stationery.append(Product)
stationery.append(Price)
stationery.append(Brand)
stationery
# Out:
# [['Pencil', 'Pen', 'Eraser', 'Pencil Box', 'Scale'],
#  [5, 10, 2, 20, 12],
#  ['Camlin', 'Rotomac', 'Nataraj', 'Camel', 'Apsara']]

# %% [raw]
# Q-12)write a code to add “Notebook” as the first element inside the first level of the list “Stationery” is:-

# %%
stationery[1][1]=

# %% [raw]
# Q-13) write a code to replace the element of Brand, “Camel” with “Camlin” inside the list is:-

# %%
for i,j in enumerate(Brand):
    print(i,j)
# Out:
# 0 Camlin
# 1 Camel
# 2 Camel
# 3 Rotomac
# 4 Nataraj
# 5 Camel
# 6 Apsara
# 7 Camel

# %%
Brand
# Out:
# ['Camlin',
#  'Camlin',
#  'Camlin',
#  'Rotomac',
#  'Nataraj',
#  'Camlin',
#  'Apsara',
#  'Camlin']

# %% [raw]
# Q-14) The list "Months" is defined as:-
#
#        Months = ['Jan', 'Mar', 'June', 'Aug', 'June', 'Feb', 'Nov', 'Dec', 'June', 'Apr', 'May',     'June']
#
#        Write a code which returns the number of occurrences of ‘June’?

# %%
Months = ['Jan', 'Mar', 'June', 'Aug', 'June', 'Feb', 'Nov', 'Dec', 'June', 'Apr', 'May','June']
x='June'
count=0
for i in Months:
  if i == x:
    count=count+1
print("Occurence of June:",count)
# Out:
# Occurence of June: 4

# %% [raw]
# Q-15) Given the variables:**
#
# planet = "Earth"
# diameter = 12742
# ** Use .format() to print the following string: **
#
# The diameter of Earth is 12742 kilometers.

# %%
print("The diameter of {planet} is {diameter} kilometers".format(planet="Earth",diameter=12742))
# Out:
# The diameter of Earth is 12742 kilometers

# %% [raw]
# Q-16)Given this nested list, use indexing to grab the word "hello"
# lst = [1,2,[3,4],[5,[100,200,['hello',1000]],23,11],1,7]

# %% [raw]
# Q-17) Given this nested dictionary grab the word "hello".
# d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}
d["k1"][3]["tricky"][3]
# Out:
# {'target': [1, 2, 3, 'hello']}

# %% [raw]
# Q-18) convert this string into a list but output of list should be in words not in alphabets.
# s = "Hi there Sam!"

# %%
s = "Hi there Sam!"

a=list(s)
a
# Out:
# ['H', 'i', ' ', 't', 'h', 'e', 'r', 'e', ' ', 'S', 'a', 'm', '!']

# %% [raw]
# Q-19) Write a code to extract the number at the end of the line below and also Convert the extracted value to a floating point number.
#
# text = "X-DSPAM-Confidence:    0.8475";

# %% [raw]
# Q-20) a=(1,5,6,7,8,"datascience")
#
# replace "datascience" to "deeplearning"
