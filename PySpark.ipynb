# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 47 kB/s
# ...
#      |████████████████████████████████| 199 kB 21.1 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=5a45c04ca5744c77c92ec14e4986d4c61f1364fff1da069e48831c2e1154e5ef
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
import pyspark
from pyspark.sql import SparkSession
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a74d4b23d03e> in <module>()
# ----> 1 import pyspark
#       2 from pyspark.sql import SparkSession
#
# ModuleNotFoundError: No module named 'pyspark'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df=SparkSession.builder.appName("Nirmal").getOrCreate()

# %%
new1=df.read.csv('/content/spark_data.csv',header=True,inferSchema=True)

# %%
new1.printSchema()
# Out:
# root
#  |-- row_id: integer (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- shipping_date: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- subcategory: string (nullable = true)
#  |-- sales: double (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- profit: double (nullable = true)

# %%
new1.select(["row_id","order_id"]).show()
# Out:
# +------+--------------+
# |row_id|      order_id|
# +------+--------------+
# |     1|CA-2016-152156|
# |     2|CA-2016-152156|
# |     3|CA-2016-138688|
# |     4|US-2015-108966|
# |     5|US-2015-108966|
# |     6|CA-2014-115812|
# |     7|CA-2014-115812|
# |     8|CA-2014-115812|
# |     9|CA-2014-115812|
# |    10|CA-2014-115812|
# |    11|CA-2014-115812|
# |    12|CA-2014-115812|
# |    13|CA-2017-114412|
# |    14|CA-2016-161389|
# |    15|US-2015-118983|
# |    16|US-2015-118983|
# |    17|CA-2014-105893|
# |    18|CA-2014-167164|
# |    19|CA-2014-143336|
# |    20|CA-2014-143336|
# +------+--------------+
# only showing top 20 rows
