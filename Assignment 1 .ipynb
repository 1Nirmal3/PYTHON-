# %% [markdown]
# **1)Write a program to that ask user to input two float numbers and perform
# addition, subtraction, division and multiplication**

# %%
a=float(input("Enter first number:"))
b=float(input("Enter second number:"))
add=a+b
sub=a-b
div=a/b
mul=a*b
print("Sum:",add)
print("Difference:",sub)
print("Quotient:",div)
print("Product:",mul)
# Out:
# Enter first number:4.0
# Enter second number:2.0
# Sum: 6.0
# Difference: 2.0
# Quotient: 2.0
# Product: 8.0

# %% [markdown]
# **2)Write a Python code to convert temperature from Fahrenheit to Celsius
# [Temp_in_Celsius = (Temp_in_Fahrenheit -32)*5/9]**

# %%
f=float(input("Enter temperature in Farenheit:",))
c=(f-32)*5/9
print("Temperature in Celsius:",c)
# Out:
# Enter temperature in Farenheit:123
# Temperature in Celsius: 50.55555555555556

# %% [markdown]
# **3)Write a program to find the area of a triangle. Ask the user to input three sides
# of a triangle and then calculate the area.
# If a, b and c are three sides of a triangle. Then,
# s = (a+b+c)/2
# area = √(s(s-a)(s-b)(s-c))**

# %%
a=int(input("Enter length of first side:"))
b=int(input("Enter length of second side:"))
c=int(input("Enter length of third side:"))
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**(1/2)
print(area)
# Out:
# Enter length of first side:2
# Enter length of second side:2
# Enter length of third side:2
# 1.7320508075688772

# %% [markdown]
# **4)Write a Python Program to Convert Kilometres to Miles**

# %%
l=float(input("Enter the distance in kilometres:"))
m=l*0.621371
print("Distance in Miles:",m)
# Out:
# Enter the distance in kilometres:100
# Distance in Miles: 62.137100000000004

# %% [markdown]
# **5)Write a program to calculate area of a circle by taking radius as the user input.**

# %%
r=float(input("Enter radius of the circle:"))
area=(22/7)*r*r
print("Area of the circle is:",area)
# Out:
# Enter radius of the circle:7
# Area of the circle is: 154.0

# %% [markdown]
# **6)Write a program to calculate area of a rectangle by taking length and breadth as
# the user input.**

# %%
l=int(input("Enter Length of the rectangle:"))
b=int(input("Enter Breadth of the rectangle:"))
ar=l*b
print("Area of the rectangle:",ar)
# Out:
# Enter Length of the rectangle:10
# Enter Breadth of the rectangle:10
# Area of the rectangle: 100

# %% [markdown]
# **7)Write a program to calculate compound interest
# A = P(1 + R/100)t
# Compound Interest = A – P
# Where,
# A is amount
# P is principle amount
# R is the rate and
# T is the time span**

# %%
P=int(input("Enter Principle Amount:"))
R=float(input("Enter interest Rate:"))
T=int(input("Enter Time Period:"))
A=P*(1+(R/100))*T
CI=A-P
print("Compound Interest:",CI)
# Out:
# Enter Principle Amount:1200
# Enter interest Rate:5.4
# Enter Time Period:2
# Compound Interest: 1329.6

# %% [markdown]
# **8)Given two points (x1, y1) and (x2, y2), the formula for computing the distance is
# √(𝑥2 − 𝑥1)^2 + (𝑦2 − 𝑦1)^2
# Ask the user to enter two points and computes the distance between them.
# Hint – You can use a^0.5 to calculate √a**

# %%
x1=int(input("Enter X-coordinate of first point:"))
y1=int(input("Enter Y-coordinate of first point:"))
x2=int(input("Enter X-coordinate of second point:"))
y2=int(input("Enter Y-coordinate of second point:"))
d=(((x2-x1)**2)+(y2-y1)**2)**(1/2)
print("Distance between points:",d)
# Out:
# Enter X-coordinate of first point:4
# Enter Y-coordinate of first point4
# Enter X-coordinate of second point2
# Enter Y-coordinate of second point2
# Distance between points: 2.8284271247461903

# %% [markdown]
# **9)Body Mass Index (BMI) is a measure of health based on weight. It can be
# calculated by taking your weight in kilograms and dividing it by the square of
# your height in meters. Write a program that prompts the user to enter the weight
# in pounds and height in inches and display the BMI. Note that one pound is
# 0.45359237 kilograms and one inch is 0.0254 meters.**

# %%
w=float(input("Enter weight(in pounds):"))
h=int(input("Enter height(in inches):"))
bmi=(w*0.45359237)/((h*0.0254)**2)
print(bmi)
# Out:
# Enter weight(in pounds):95.5
# Enter height(in inches):50
# 26.857257942215885

# %% [markdown]
# **10)Write a program must satisfy the following requirements:
# ■It must let the user enter the interest rate, the loan amount, and the number of
# years for which payments will be made.
# ■ It must compute and display the monthly payment and total payment amounts.**

# %%
r=float(input("Enter Annual Interest Rate:"))
t=int(input("Enter no. of years:"))
p=int(input("Enter principal amount:"))
m_itr= r/1200
m_amount=(p*m_itr)/(1-(1/(1+m_itr))**(t*12))
print("Monthly Payment:",m_amount)
total=m_amount*t*12
print("Total Payment:",total)
# Out:
# Enter Annual Interest Rate:5.75
# Enter no. of years:15
# Enter principal amount:250000
# Monthly Payment: 2076.0252175491346
# Total Payment: 373684.5391588443
